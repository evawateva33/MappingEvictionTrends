# %% [markdown]
# # Twitter webscraping -- Rene's workplace

# %%
import tweepy
from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
import csv
import sys
import time
import argparse
import string
import json
import geopandas as gpd
import geocoder
import numpy as np

# %% [markdown]
# Below, the codes are referenced from an outside file containing the authentication codes, as to avoid a potential leak.

# %%
d = json.load(open("codes.txt"))
consumer_key = d['1'] 
consumer_secret = d['2'] 
access_token = d['3'] 
access_secret = d['4']

# %% [markdown]
# This below contains the Twitter hashtags considered important, with the English and Spanish hashtags intended to query for Spanish-speaking accounts referencing these tags.

# %%
hshtgs = ["Evictions", 
            "Homelessness", 
            "Homeless", 
            "Tenant", 
            "TenantPower",
            "AffordableHousing", 
            "CancelRent", 
            "RentStrike", 
            "TaxTheRich", 
            "EvictionMoratorium", 
            "RentMoratorium", 
            "EvictionFree", 
            "NoEvictions", 
            "Housing assistance", 
            "Housingrelief", 
            "COVID19", 
            "Rentstrike", 
            "Housingcrisis", 
            "Rentburden", 
            "HousingForAll", 
            "Evictionfreeze", 
            "HousingAffordability", 
            "EquitableDevelopment", 
            "Unemployment", 
            "Foreclosure", 
            "SuspendRent", 
            "RentFreeze", 
            "Displacement", 
            "RentalAssistance", 
            "ReclaimOurHomes",
            "StopEvictions", 
            "CantPayWontPay"]
spanish_hshtgs = ["CancelLaRenta",
                "SinDesalojos",
                "ComidaSiRentaNo",
                "NoCobramosNoPagamos",
                "RentaEstabilizada",
                "HuelgadeAlquileres",
                "CancelenDeudas",
                "LaRentaNoSeCome",
                "CansadosDeLimosnas",
                "QueremosJusticia",
                "ImpactoLatino"]

# %%
#Spanish tweets
import pandas as pd

for i in range(len(spanish_hshtgs)):
    hshtg = spanish_hshtgs[i]
    cmd = "#{}".format(hshtg)
    print(cmd)
    # !snscrape --since "2019-12-31" twitter-search $cmd >> sp_links.txt
    
for i in range(len(hshtgs)):
    hshtg = hshtgs[i]
    cmd = "#{}".format(hshtg)
    print(cmd)
    # !snscrape --since "2019-12-31" twitter-search $cmd >> en_links.txt
# Out:
# #CancelLaRenta
# #SinDesalojos
# #ComidaSiRentaNo
# #NoCobramosNoPagamos
# #RentaEstabilizada
# #HuelgadeAlquileres
# #CancelenDeudas
# #LaRentaNoSeCome
# #CansadosDeLimosnas
# #QueremosJusticia
# #ImpactoLatino
# #Evictions
# #Homelessness

# %%
with open('sp_links.txt', 'r') as f:
    tweets_sp = [line.strip() for line in f]
with open('en_links.txt', 'r') as f:
    tweets_en = [line.strip() for line in f]
    
print("Text file containing tweets with Spanish hashtags: " + str(len(tweets_sp)))
print("Text file containing tweets with English hashtags: " + str(len(tweets_en)))

# %%
import os 

df = pd.DataFrame()
def get_tweets(tweet_ids):
    #     global api
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    api = tweepy.API(auth, wait_on_rate_limit = True, wait_on_rate_limit_notify = True)
    statuses = api.statuses_lookup(tweet_ids, tweet_mode="extended")
    data = df # define your own dataframe
    # printing the statuses
    for status in statuses:
        # print(status.lang)        if status.lang == "en":
        if status.place == "Paterson, NJ":
            mined = {
                "tweet_id": status.id,
                "name": status.user.name,
                "screen_name": status.user.screen_name,
                "retweet_count": status.retweet_count,
                "text": status.full_text,
                "mined_at": datetime.datetime.now(),
                "created_at": status.created_at,
                "favourite_count": status.favorite_count,
                "hashtags": status.entities["hashtags"],
                "status_count": status.user.statuses_count,
                "followers_count": status.user.followers_count,
                "location": status.place,
                "source_device": status.source,
            }            
            last_tweet_id = status.id
            data = data.append(mined, ignore_index=True)    
    data.to_csv(
        f"Extracted_TWEETS.csv", mode="a", header=not os.path.exists("Extracted_TWEETS.csv"), index=False
    )
    print("..... going to sleep 20s")
    time.sleep(20)
    
for i in tweet_ids :
    get_tweets(i)

# %% [markdown]
# ## Nothing important below.

# %%
# config
location_ = "40.914745,-74.162827,10mi" #"40.914745,-74.162827,10mi"
date_ = "2020-01-01" #"2018-11-16"

def search_tweets(title, query, date_since = "01-01-2020"):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    api = tweepy.API(auth, wait_on_rate_limit = True, wait_on_rate_limit_notify = True)
    
    search_term = query
    with open(title + ".csv", 'a', encoding = "utf-8",  newline='') as csvfile:
        tweetData = csv.writer(csvfile)
        for tweet in tweepy.Cursor(api.search, q = query and ("place:%s" % "Paterson, NJ"), tweet_mode="extended",  since=date_since).items():
            if tweet.coordinates is not None:
                tweetData.writerow([search_term, tweet.created_at, tweet.full_text, tweet.coordinates["coordinates"], tweet.user.screen_name])
            elif tweet.place is not None:
                tweetData.writerow([search_term, tweet.created_at, tweet.full_text, tweet.place.full_name, tweet.user.screen_name])
            else:
                tweetData.writerow([search_term, tweet.created_at, tweet.full_text, tweet.user.location, tweet.user.screen_name])
    csvfile.close()

# %%
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth, wait_on_rate_limit =True)

@classmethod
def parse(cls, api, raw):
    status = cls.first_parse(api, raw)
    setattr(status, 'json', json.dumps(raw))
    return status
 

class Listener(StreamListener):
    def on_data(self, data):
        try:
            # Parsing the json recieved from the twitter stream
            jsonData = json.loads(data)
            print(jsonData)
            createdAt = jsonData['created_at']
            text = jsonData['text']
            print("Created at : " , createdAt , " text : " , text)
            saveThis = createdAt + " ---> " + text
            
            saveFile = open("results.csv","a")
            saveFile.write(saveThis.encode('utf-16'))
            saveFile.write("\n")
            saveFile.close()
            title_ = "tweets_.csv"
            with open(title_, 'a', encoding = "utf-8",  newline='') as csvfile:
                w = csv.DictWriter(csvfile, fieldnames = sorted(D.keys()))
                w.writeheader()
                w.writerow(D)
            csvfile.close()
            return True
        except BaseException as e:
            print('Failed on data : ', str(e))
            time.sleep(5)

    def on_error(self, status):
        print("Error : ", status)

# Listener for twitter streaming             
language_ = ["en"]
tracks_ = ["CancelRent", "RentStrike"]


g_ = g.json.get('raw').get('boundingbox')
order = [0, 2, 1, 3]
locations_ = [float(g_[_]) for _ in order]
print(locations_)

if __name__ == '__main__':
    twitter_stream = Stream(auth, Listener())
    twitter_stream.filter(track = tracks_, locations = locations_)
# Out:
# [40.888682, -74.206197, 40.94159, -74.129233]
# {'created_at': 'Mon Sep 28 23:28:56 +0000 2020', 'id': 1310723194593193984, 'id_str': '1310723194593193984', 'text': 'RT @ny_indivisible: BREAKING: @NYGovCuomo Now extends Residential Eviction Moratorium for 2020. \n\nNow he MUST #CancelRent \n\nSupport NYS Bil…', 'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 37020219, 'id_str': '37020219', 'name': 'xECKx', 'screen_name': 'xECK29x', 'location': 'Long Island, NY', 'url': None, 'description': 'He/Him, #Isles, infosec DFIR, straight-edge, EHM DB guy. Mostly RTs.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1050, 'friends_count': 5001, 'listed_count': 126, 'favourites_count': 41369, 'statuses_count': 50832, 'created_at': 'Fri May 01 19:33:13 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1810970119/Untitled_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1810970119/Untitled_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/37020219/1408378689', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Sep 28 15:56:05 +0000 2020', 'id': 1310609234011344899, 'id_str': '1310609234011344899', 'text': 'BREAKING: @NYGovCuomo Now extends Residential Eviction Moratorium for 2020. \n\nNow he MUST #CancelRent \n\nSupport NYS… https://t.co/PAZOxsmxVH', 'display_text_range': [0, 140], 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 817089118178054145, 'id_str': '817089118178054145', 'name': '🌈👍🏽NY #StopTheTrumpCoup Indivisible', 'screen_name': 'ny_indivisible', 'location': 'New York, USA', 'url': 'https://is.gd/l1vpcP', 'description': 'NYC-based/New York State focused progressive amplifier. Policy matters. #cancelrent Critical of the establishment.\n\nIG: @ny_indivisible', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 6756, 'friends_count': 3663, 'listed_count': 153, 'favourites_count': 76186, 'statuses_count': 51446, 'created_at': 'Thu Jan 05 19:23:21 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/930481999701213184/iROGDqRf_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/930481999701213184/iROGDqRf_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/817089118178054145/1591562696', 'default_profile': True ...
# Created at :  Mon Sep 28 23:28:56 +0000 2020  text :  RT @ny_indivisible: BREAKING: @NYGovCuomo Now extends Residential Eviction Moratorium for 2020.
#
# Now he MUST #CancelRent
#
# Support NYS Bil…
# Failed on data :  write() argument must be str, not bytes
# {'created_at': 'Mon Sep 28 23:29:01 +0000 2020', 'id': 1310723217011564544, 'id_str': '1310723217011564544', 'text': '#HousingCrisis #CancelRent', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2530758806, 'id_str': '2530758806', 'name': 'FM', 'screen_name': 'lily_oh_lily_', 'location': 'Pacific Northwest', 'url': None, 'description': 'It is the mark of an educated mind to be able to entertain a thought without accepting it. - Aristotle', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 445, 'friends_count': 167, 'listed_count': 73, 'favourites_count': 58492, 'statuses_count': 84287, 'created_at': 'Wed May 28 20:07:06 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/493470165799948288/ixmF8XE8_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/493470165799948288/ixmF8XE8_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2530758806/1406589741', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1310604526186049537, 'quoted_status_id_str': '1310604526186049537', 'quoted_status': {'created_at': 'Mon Sep 28 15:37:23 +0000 2020', 'id': 1310604526186049537, 'id_str': '1310604526186049537', 'text': 'NEW: Gov. Cuomo is extending the residential eviction moratorium until January 1, 2021. \n\n“I want people to have fu… https://t.co/rUwE32yo7L', 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2325548840, 'id_str': '2325548840', 'name': 'Josefa Velásquez', 'screen_name': 'J__Velasquez', 'location': None, 'url': 'http://thecity.nyc', 'description': 'Senior reporter @TheCityNY. \nPoniéndome las pilas.\nTips? JVelasquez@TheCity.NYC or DM for Signal.', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 10702, 'friends_count': 1751, 'listed_count': 335, 'favourites_count': 4900, 'statuses_count': 17852, 'created_at': 'Mon Feb 03 14:23:56 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1245882317022904320/Enw1Zh16_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1245882317022904320/Enw1Zh16_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2325548840/1498176262', 'default_profile': False, 'defa ...
# Created at :  Mon Sep 28 23:29:01 +0000 2020  text :  #HousingCrisis #CancelRent
# Failed on data :  write() argument must be str, not bytes
# {'created_at': 'Mon Sep 28 23:30:05 +0000 2020', 'id': 1310723483077312512, 'id_str': '1310723483077312512', 'text': 'So terribly sad to see the closing of #Chelsea iconic diner: The Rail Line  Diner. They could have survived w/… https://t.co/KrLMUoikkK', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 880878763977920512, 'id_str': '880878763977920512', 'name': 'Marni Halasa', 'screen_name': 'Marni4Council', 'location': 'Manhattan, NY', 'url': 'http://www.marniforcitycouncil.com', 'description': 'Donate $10 to a PEOPLES POWER CAMPAIGN in my run 4 City Council 2021: http://marniforcitycouncil.com #SBJSA #NYCHA #BlameCorey #CancelRent marnihalasa@gmail.com', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1144, 'friends_count': 1540, 'listed_count': 14, 'favourites_count': 10109, 'statuses_count': 9215, 'created_at': 'Fri Jun 30 20:00:38 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '117342', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/903368176276316160/CBftFzDq_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/903368176276316160/CBftFzDq_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/880878763977920512/1594688747', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'So terribly sad to see the closing of #Chelsea iconic diner: The Rail Line  Diner. They could have survived w/#CancelRent w/#RentVoucher &amp; #SBJSA but electeds don’t really care about #SmallBusinesses &amp; #jobs.  @CCNewsNYC @ChelseaNowNYC @TheVillageSun @chelseanews @NYDailyNews https://t.co/skqbRQjKvl', 'display_text_range': [0, 284], 'entities': {'hashtags': [{'text': 'Chelsea', 'indices': [38, 46]}, {'text': 'CancelRent', 'indices': [110, 121]}, {'text': 'RentVoucher', 'indices': [124, 136]}, {'text': 'SBJSA', 'indices': [143, 149]}, {'text': 'SmallBusinesses', 'indices': [187, 203]}, {'text': 'jobs', 'indices': [210, 215]}], 'urls': [], 'user_mentions': [{'screen_name': 'CCNewsNYC', 'name': 'ChelseaCommunityNews.com', 'id': 1108458740397850630, 'id_str': '1108458740397850630', 'indices': [218, 228]}, {'screen_name': 'ChelseaNowNYC', 'name': 'Chelsea Now', 'id': 622235859, 'id_str': '622235859', 'indices': [229, 243]}, {'screen_name': 'TheVillageSun', 'name': 'The Village Sun', 'id': 1177392946905341953, 'id_str': '1177392946905341953', 'indices': [244, 258]}, {'screen_name': 'chelseanews', 'name': 'Chelsea News', 'id': 14050636, 'id_str': '14050636', 'indices': [259, 271]}, {'screen_name': 'NYDailyNews', 'name': 'New York Daily News', 'id': 9763482, 'id_str': '9763482', 'indices': [272, 284]}], 'symbols': [], 'media': [{'id': 1310723471283023872, 'id_str': '1310723471283023872', 'indices': [285, 308], 'media_url': 'http://pbs.twimg.com/media/EjCgDXiXcAA73I-.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjCgDXiXcAA73I-.jpg', 'url': 'https://t.co/skqbRQjKvl', 'display_url': 'pic.twitter.com/skqbRQjKvl', 'expanded_url': 'https://twitter.com/Marni4Council/status/131 ...
# Created at :  Mon Sep 28 23:30:05 +0000 2020  text :  So terribly sad to see the closing of #Chelsea iconic diner: The Rail Line  Diner. They could have survived w/… https://t.co/KrLMUoikkK
# Failed on data :  write() argument must be str, not bytes
# {'created_at': 'Mon Sep 28 23:32:43 +0000 2020', 'id': 1310724145668210689, 'id_str': '1310724145668210689', 'text': 'RT @jeremoss: Folks from @abolitionpark are having a housewarming -- in front of Andrew Cuomo’s office at 633 3rd Ave in Manhattan. They ha…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1196932621625769984, 'id_str': '1196932621625769984', 'name': 'Love is love // BLM // Pro-Fem', 'screen_name': 'lvislvblmprofem', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 5, 'friends_count': 118, 'listed_count': 0, 'favourites_count': 4434, 'statuses_count': 1446, 'created_at': 'Tue Nov 19 23:26:17 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1310327422173151232/MLNpvrVL_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1310327422173151232/MLNpvrVL_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1196932621625769984/1596143999', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Sep 28 21:20:49 +0000 2020', 'id': 1310690952831471616, 'id_str': '1310690952831471616', 'text': 'Folks from @abolitionpark are having a housewarming -- in front of Andrew Cuomo’s office at 633 3rd Ave in Manhatta… https://t.co/fUiZLdlIOA', 'display_text_range': [0, 140], 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 23972042, 'id_str': '23972042', 'name': 'Jeremiah Moss 🌹', 'screen_name': 'jeremoss', 'location': 'New York City', 'url': 'http://vanishingnewyork.blogspot.com/', 'description': 'Vanishing New York, cities, gentrification, neoliberalism, queer stuff. Recent work at n+1: https://nplusonemag.com/authors/mossjeremiah/', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 11393, 'friends_count': 2601, 'listed_count': 371, 'favourites_count': 12230, 'statuses_count': 324, 'created_at': 'Thu Mar 12 15:55:20 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'A36C06', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '3565E2', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/887508965210435584/DS2nw_25_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/887508965210435584/DS2nw_25_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/23972042/1500653657', 'default_profile': False, 'default_profile_image': False, 'foll ...
# Created at :  Mon Sep 28 23:32:43 +0000 2020  text :  RT @jeremoss: Folks from @abolitionpark are having a housewarming -- in front of Andrew Cuomo’s office at 633 3rd Ave in Manhattan. They ha…
# Failed on data :  write() argument must be str, not bytes
# {'created_at': 'Mon Sep 28 23:33:17 +0000 2020', 'id': 1310724290602569729, 'id_str': '1310724290602569729', 'text': 'RT @nycDSA: You know what would provide real, fundamental stability for the lives of working-class New Yorkers instead of putting them at r…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 498456198, 'id_str': '498456198', 'name': 'Rocco Marinara', 'screen_name': 'tokingalex', 'location': None, 'url': None, 'description': '26 queer bruh (he/they) | professionally mediocre musician | unemployed healthcare worker | music therapist who needs therapy | BLM | TransNBlivesmatter | M4A', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1042, 'friends_count': 1250, 'listed_count': 7, 'favourites_count': 43549, 'statuses_count': 23569, 'created_at': 'Tue Feb 21 02:33:08 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/2160928054/548999_3455268147743_1452017765_33254698_1898760120_n__1__normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2160928054/548999_3455268147743_1452017765_33254698_1898760120_n__1__normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/498456198/1593040639', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Sep 28 16:19:00 +0000 2020', 'id': 1310614998071291907, 'id_str': '1310614998071291907', 'text': 'You know what would provide real, fundamental stability for the lives of working-class New Yorkers instead of putti… https://t.co/JyLjEMRO0M', 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2977725884, 'id_str': '2977725884', 'name': 'NYC-DSA 🌹 Reopen Schools #OnlyWhenItsSafe', 'screen_name': 'nycDSA', 'location': 'New York City', 'url': 'http://socialists.nyc', 'description': 'NYC local of @DemSocialists, the largest socialist org in the United States!🌹| 🇫: https://t.co/70fuLUBwUy | 📸: https://t.co/nCX8yrS4pc | #DefundNYPD: https://t.co/EnQsNmACPY', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 34984, 'friends_count': 1563, 'listed_count': 353, 'favourites_count': 9054, 'statuses_count': 16289, 'created_at': 'Mon Jan 12 21:49:23 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'DD2E44', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/pr ...
# Created at :  Mon Sep 28 23:33:17 +0000 2020  text :  RT @nycDSA: You know what would provide real, fundamental stability for the lives of working-class New Yorkers instead of putting them at r…
# Failed on data :  write() argument must be str, not bytes
# {'created_at': 'Mon Sep 28 23:35:49 +0000 2020', 'id': 1310724926077390849, 'id_str': '1310724926077390849', 'text': 'RT @ny_indivisible: BREAKING: @NYGovCuomo Now extends Residential Eviction Moratorium for 2020. \n\nNow he MUST #CancelRent \n\nSupport NYS Bil…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 339340704, 'id_str': '339340704', 'name': 'Cheryl Smith', 'screen_name': 'Cheryl_Smith1', 'location': 'New York', 'url': None, 'description': 'BAT. 30+ year science teacher, FUSE Negotiation Chairperson,  NYSUT union member, 18 year school board retired trustee. Fighting for our kids & public education', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2446, 'friends_count': 2915, 'listed_count': 140, 'favourites_count': 142224, 'statuses_count': 195126, 'created_at': 'Wed Jul 20 23:28:49 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/796090992562552832/JE1otcEB_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/796090992562552832/JE1otcEB_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/339340704/1391654080', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Sep 28 15:56:05 +0000 2020', 'id': 1310609234011344899, 'id_str': '1310609234011344899', 'text': 'BREAKING: @NYGovCuomo Now extends Residential Eviction Moratorium for 2020. \n\nNow he MUST #CancelRent \n\nSupport NYS… https://t.co/PAZOxsmxVH', 'display_text_range': [0, 140], 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 817089118178054145, 'id_str': '817089118178054145', 'name': '🌈👍🏽NY #StopTheTrumpCoup Indivisible', 'screen_name': 'ny_indivisible', 'location': 'New York, USA', 'url': 'https://is.gd/l1vpcP', 'description': 'NYC-based/New York State focused progressive amplifier. Policy matters. #cancelrent Critical of the establishment.\n\nIG: @ny_indivisible', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 6756, 'friends_count': 3663, 'listed_count': 153, 'favourites_count': 76186, 'statuses_count': 51446, 'created_at': 'Thu Jan 05 19:23:21 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/930481999701213184/iROGDqRf_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/930481999701213184/iROGDqRf_norm ...
# Created at :  Mon Sep 28 23:35:49 +0000 2020  text :  RT @ny_indivisible: BREAKING: @NYGovCuomo Now extends Residential Eviction Moratorium for 2020.
#
# Now he MUST #CancelRent
#
# Support NYS Bil…
# Failed on data :  write() argument must be str, not bytes
# {'created_at': 'Mon Sep 28 23:37:33 +0000 2020', 'id': 1310725362666688512, 'id_str': '1310725362666688512', 'text': 'RT @Marni4Council: So terribly sad to see the closing of #Chelsea iconic diner: The Rail Line  Diner. They could have survived w/#CancelRen…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 709828169, 'id_str': '709828169', 'name': 'Purplegarter', 'screen_name': 'Purplegarter1', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 3753, 'friends_count': 3524, 'listed_count': 949, 'favourites_count': 328736, 'statuses_count': 595113, 'created_at': 'Fri Oct 11 20:35:04 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/413699302611886080/geQ9MFWE_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/413699302611886080/geQ9MFWE_normal.jpeg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Sep 28 23:30:05 +0000 2020', 'id': 1310723483077312512, 'id_str': '1310723483077312512', 'text': 'So terribly sad to see the closing of #Chelsea iconic diner: The Rail Line  Diner. They could have survived w/… https://t.co/KrLMUoikkK', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 880878763977920512, 'id_str': '880878763977920512', 'name': 'Marni Halasa', 'screen_name': 'Marni4Council', 'location': 'Manhattan, NY', 'url': 'http://www.marniforcitycouncil.com', 'description': 'Donate $10 to a PEOPLES POWER CAMPAIGN in my run 4 City Council 2021: http://marniforcitycouncil.com #SBJSA #NYCHA #BlameCorey #CancelRent marnihalasa@gmail.com', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1144, 'friends_count': 1540, 'listed_count': 14, 'favourites_count': 10112, 'statuses_count': 9217, 'created_at': 'Fri Jun 30 20:00:38 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '117342', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/903368176276316160/CBftFzDq_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/903368176276316160/CBftFzDq_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/880878763977920512/1594688747', 'default_profile': False, 'default_profile_image ...
# Created at :  Mon Sep 28 23:37:33 +0000 2020  text :  RT @Marni4Council: So terribly sad to see the closing of #Chelsea iconic diner: The Rail Line  Diner. They could have survived w/#CancelRen…
# Failed on data :  write() argument must be str, not bytes
# {'created_at': 'Mon Sep 28 23:51:55 +0000 2020', 'id': 1310728980790685696, 'id_str': '1310728980790685696', 'text': 'RT @PilsenAlliance: 🚨 PILSEN RALLY THURSDAY OCT. 1 AGAINST GENTRIFICATION &amp; DISPLACEMENT 🚨\xa0\n\nRally 4pm at 18th &amp; Loomis (Plaza Tenochtitlán…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 828665423839244288, 'id_str': '828665423839244288', 'name': 'les-beaner', 'screen_name': '1_800_aries', 'location': 'ur heart', 'url': None, 'description': 'they/them femme', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 109, 'friends_count': 305, 'listed_count': 1, 'favourites_count': 47316, 'statuses_count': 11840, 'created_at': 'Mon Feb 06 18:03:27 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1269548306406965249/DQnponbP_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269548306406965249/DQnponbP_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/828665423839244288/1588809828', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Sep 28 22:04:54 +0000 2020', 'id': 1310702049621876738, 'id_str': '1310702049621876738', 'text': '🚨 PILSEN RALLY THURSDAY OCT. 1 AGAINST GENTRIFICATION &amp; DISPLACEMENT 🚨\xa0\n\nRally 4pm at 18th &amp; Loomis (Plaza Tenochti… https://t.co/Gz2tgY5Rj0', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2557471844, 'id_str': '2557471844', 'name': 'Pilsen Alliance', 'screen_name': 'PilsenAlliance', 'location': 'Pilsen - Chicago, Illinois', 'url': 'http://www.thepilsenalliance.org/about', 'description': 'Pilsen Alliance is a social justice organization committed to developing grassroots leadership in Pilsen and neighboring working class, immigrant communities.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 3458, 'friends_count': 2418, 'listed_count': 42, 'favourites_count': 2072, 'statuses_count': 3146, 'created_at': 'Mon Jun 09 20:25:19 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1078401441847377920/mlnNNJib_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1078401441847377920/mlnNNJib_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2557471844/1545947186', 'default_p ...
# Created at :  Mon Sep 28 23:51:55 +0000 2020  text :  RT @PilsenAlliance: 🚨 PILSEN RALLY THURSDAY OCT. 1 AGAINST GENTRIFICATION &amp; DISPLACEMENT 🚨
#
# Rally 4pm at 18th &amp; Loomis (Plaza Tenochtitlán…
# Failed on data :  write() argument must be str, not bytes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-891fc8deffe0> in <module>
#      52 if __name__ == '__main__':
#      53     twitter_stream = Stream(auth, Listener())
# ---> 54     twitter_stream.filter(track = tracks_, locations = locations_)
#
# ~\Anaconda3\envs\python_\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\envs\python_\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Anaconda3\envs\python_\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\envs\python_\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\Anaconda3\envs\python_\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\Anaconda3\envs\python_\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     516             else:
#     517                 cache_content = False
# --> 518                 data = self._fp.read(amt) if not fp_closed else b""
#     519                 if (
#     520                     amt != 0 and not data
#
# ~\Anaconda3\envs\python_\lib\http\client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# ~\Anaconda3\envs\python_\lib\http\client.py in readinto(self, b)
#     490
#     491         if self.chunked:
# --> 492             return self._readinto_chunked(b)
#     493
#     494         if self.length is not None:
#
# ~\Anaconda3\envs\python_\lib\http\client.py in _readinto_chunked(self, b)
#     585         try:
#     586             while True:
# --> 587                 chunk_left = self._get_chunk_left()
#     588                 if chunk_left is None:
#     589                     return total_bytes
#
# ~\Anaconda3\envs\python_\lib\http\client.py in _get_chunk_left(self)
#     553                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     554             try:
# --> 555                 chunk_left = self._read_next_chunk_size()
#     556             except ValueError:
#     557                 raise IncompleteRead(b'')
#
# ~\Anaconda3\envs\python_\lib\http\client.py in _read_next_chunk_size(self)
#     513     def _read_next_chunk_size(self):
#     514         # Read the next chunk size from the file
# --> 515         line = self.fp.readline(_MAXLINE + 1)
#     516         if len(line) > _MAXLINE:
#     517             raise LineTooLong("chunk size")
#
# ~\Anaconda3\envs\python_\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\Anaconda3\envs\python_\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\Anaconda3\envs\python_\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
